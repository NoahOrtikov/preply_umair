# %% [markdown]
# ### Task 1

# %%
# we have to upload the voice of noah to python and we have to see how it looks like sing matplotlib

# %%
from scipy.io import wavfile

# %%
frequency,data = wavfile.read("Enclave-Dr.wav")
import matplotlib.pyplot as plt

# %%
data
# Out:
# array([ 0,  0,  0, ..., -7, -8, -8], dtype=int16)

# %%
plt.plot(data)

# %% [markdown]
# ### Task 2

# %%
# i have a numpy array data, how can i play it in python (please search on web)

# %%
import numpy as np
import sounddevice as sd

sd.default.samplerate = 44100

data2 = data

wav_wave = np.array(data2, dtype=np.int16)

sd.play(wav_wave, blocking=True)

# %%
pip install sounddevice
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Task 3

# %%
# from this sound can you fine the peak points

# %%
# please on internet find how to find the indexes of peak points of numpy array

# %%
from scipy.signal import find_peaks
b,*a=find_peaks(data,1000,50)
plt.plot(data)
plt.plot(b,data[b],'x')

# %%
b
# Out:
# (array([  1996,   1999,   2030, ..., 362472, 362480, 362487]), {})

# %% [markdown]
# ### Task 4

# %%
#make a list of 10 animals and print them if there is e present in their name using for loop

# %%
z = ['bee','beetle','butterfly','bunny','hare','monkey','elephant','tiger','panda','horse']
for e in z:
    if 'n' in e:
        print(e)
# Out:
# bunny
# monkey
# elephant
# panda
