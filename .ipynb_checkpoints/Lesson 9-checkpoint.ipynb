# %%
# loops

# %%
for i in range(10):
    print("Noah")
    print("Umair")
    print("Sahil")
# Out:
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# Umair
# Sahil
# Noah
# ...

# %%
# list of 3 friends
f = ['']

# %%
# Out:
# ['Noah', 'Umair', 'Sahil']

# %%
for i in f:
    print (i,"Studnet")
# Out:
# Noah Studnet
# Umair Studnet
# Sahil Studnet

# %%
# write the name of people who are learning python
# noah is learning python
#umair is leanring python
# mrx is learning pyhton
pp = ['Noah','Yogurt','Umair']
for i in pp:
    print(i,"is leanring python.")
# Out:
# Noah is leanring python.
# Yogurt is leanring python.
# Umair is leanring python.

# %%
toppings = ['pepperoni','sausage','cheese']
for i in toppings:
    print(i,"is my fav pizza topping")
# Out:
# pepperoni is my fav pizza topping
# sausage is my fav pizza topping
# cheese is my fav pizza topping

# %%
# your fav 3 colors

# %%
gggg = ['Green','Navy','Blue']
for i in gggg:
    print(i,'is my fav color')
# Out:
# Green is my fav color
# Navy is my fav color
# Blue is my fav color

# %%
def function1(x,y):
    print("sum is",x+y)
    print("difference is",x-y)
    print("product is",x*y)

# %%
function1(2,1)
# Out:
# sum is 3
# difference is 1
# product is 2

# %%
function1(5,10)
# Out:
# sum is 15
# difference is -5
# product is 50

# %%
function1(20,21)
# Out:
# sum is 41
# difference is -1
# product is 420

# %%
def noah(x):
    print("hello",x)

# %%
noah('M$')
# Out:
# hello M$

# %%
noah("Iryna")
# Out:
# hello Iryna

# %%
noah("Eli")
# Out:
# hello Eli

# %%
# i want to make account on tinkercad to work with codeblocks
